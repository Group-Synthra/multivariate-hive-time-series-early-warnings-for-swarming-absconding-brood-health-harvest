# %% [markdown]
# # Absconding Prediction Module — Google Colab
#
# Upload `hive_data_with_features.csv`, `absconding_pipeline.py`, and optionally `lstm_absconding.py`.

# %%
# !pip install pandas numpy scikit-learn matplotlib joblib tensorflow -q

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# ## Fast baseline / Random Forest pipeline

# %%
# !python absconding_pipeline.py --data hive_data_with_features.csv --output absconding_outputs --model fast

# %%
import json
from pathlib import Path
print(Path('absconding_outputs/absconding_dashboard.json').read_text()[:2000])

# %% [markdown]
# ## Final report Random Forest run

# %%
# !python absconding_pipeline.py --data hive_data_with_features.csv --output absconding_outputs_rf --model rf

# %% [markdown]
# ## Optional LSTM comparison

# %%
# !python lstm_absconding.py --data hive_data_with_features.csv --output absconding_lstm_outputs --epochs 30

# %% [markdown]
# Download output folder as a zip.

# %%
# !zip -r absconding_outputs.zip absconding_outputs
files.download('absconding_outputs.zip')
